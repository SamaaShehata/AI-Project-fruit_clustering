# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.datasets import load_files
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import cv2

# %%
#Import training data
directory=r'C:\Users\samaa\Downloads\fruits\fruits-360\Training'
classes=["AppleGolden1","Avocado","Banana","Cherry 1","Cocos","Kiwi",
         "Lemon","Mango","Orange"]

all_arrays=[]
img_size=100
for i in classes:
    path=os.path.join(directory,i)
    class_num=classes.index(i)
    for img in os.listdir(path):
      # img_array=cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
        img_array=cv2.imread(os.path.join(path,img))
        img_array=cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
        img_array=cv2.resize(img_array,(img_size,img_size))
        all_arrays.append([img_array,class_num])

# %%
#Import testing data
directory2=r'C:\Users\samaa\Downloads\fruits\fruits-360\Test'
classes2=["Apple Golden 1","Avocado","Banana","Cherry 1","Cocos","Kiwi",
         "Lemon","Mango","Orange"]

all_arrays2=[]
img_size=100
for i in classes2:
    path=os.path.join(directory2,i)
    class_num2=classes2.index(i)
    for img in os.listdir(path):
        #img_array2=cv2.imread(os.path.join(path,img),
        #                     cv2.IMREAD_GRAYSCALE)
        img_array2=cv2.imread(os.path.join(path,img))
        img_array2=cv2.cvtColor(img_array2, cv2.COLOR_BGR2RGB)
        img_array2=cv2.resize(img_array2,(img_size,img_size))
        all_arrays2.append([img_array2,class_num2])

# %%
#Deviding training data into imges and lables to be used in the model
train_images = []
train_labels = []

for features,label in all_arrays:
    train_images.append(features)
    train_labels.append(label)

#converting train_images &train_lables from lists into np arra to fit in the modle
train_images = np.array(train_images)
train_labels = np.array(train_labels)

# %%
#Deviding testing data into imges and lables to be used in the model
test_images = []
test_labels = []

for features,label in all_arrays2:
    test_images.append(features)
    test_labels.append(label)
    
test_images = np.array(test_images)
test_labels = np.array(test_labels)

# %%
#normalization
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
#normalization
train_images = tf.keras.utils.normalize(train_images, axis=1)
test_images = tf.keras.utils.normalize(test_images, axis=1)

# %%
#shuffle the data and print a sample
import random
random.shuffle(all_arrays)
for sample in all_arrays[:10]:
    print(sample[1])
# Out:
# 3
# 2
# 3
# 6
# 0
# 2
# 7
# 8
# 3
# 7

# %%
#print the shapes
print(train_images.shape)
print(len(train_labels))
print(train_labels)
print(test_images.shape)
print(len(test_labels))
# Out:
# (4306, 100, 100, 3)
# 4306
# [0 0 0 ... 8 8 8]
# (1445, 100, 100, 3)
# 1445

# %%
#displaying an image
plt.imshow(train_images[4100], cmap=plt.cm.binary)  # graph it
plt.show()  # display!

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(100, 100, 3)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy', # diff between actual and probabilities
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, batch_size = 128, epochs = 10)
# Out:
# Epoch 1/5
# 4306/4306 [==============================] - 43s 10ms/step - loss: 1.5159 - acc: 0.5553
# Epoch 2/5
# 4306/4306 [==============================] - 5s 1ms/step - loss: 0.3463 - acc: 0.9345
# Epoch 3/5
# 4306/4306 [==============================] - 5s 1ms/step - loss: 0.1288 - acc: 0.9905
# Epoch 4/5
# 4306/4306 [==============================] - 5s 1ms/step - loss: 0.0605 - acc: 0.9988
# Epoch 5/5
# 4306/4306 [==============================] - 6s 1ms/step - loss: 0.0359 - acc: 0.9998

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('Test accuracy:', test_acc)
# Out:
# 1445/1445 [==============================] - 9s 7ms/step
# Test accuracy: 0.9847750865051903

# %%
predictions = model.predict(test_images)
print(predictions[0])
print(np.argmax(predictions[0]))
print(test_labels[0])
# Out:
# [9.4232136e-01 9.8575965e-06 2.1122743e-03 8.7184745e-08 1.6866732e-05
#  1.7362522e-02 3.6927160e-02 1.4397338e-04 1.1058552e-03 2.9994808e-08]
# 0
# 0
