# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.datasets import load_files
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import cv2

# %%
#Import training data
directory=r'C:\Users\samaa\Downloads\fruits\fruits-360\Training'
classes=["AppleRed1","Apricot","Avocado","Banana",
         "Blueberry","Cherry 1","Carambula","Cocos",
         "Corn","Dates","Lemon","Mango","Orange","Watermelon"]

all_arrays=[]
img_size=100
for i in classes:
    path=os.path.join(directory,i)
    class_num=classes.index(i)
    for img in os.listdir(path):
        img_array=cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
        img_array=cv2.imread(os.path.join(path,img))
       # img_array=cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
        img_array=cv2.resize(img_array,(img_size,img_size))
        all_arrays.append([img_array,class_num])

# %%
#Import testing data
directory2=r'C:\Users\samaa\Downloads\fruits\fruits-360\Test'
classes2=["AppleRed1","Apricot","Avocado","Banana",
          "Blueberry","Cherry 1","Carambula","Cocos",
          "Corn","Dates","Lemon","Mango","Orange","Watermelon"]

all_arrays2=[]
img_size=100
for i in classes2:
    path=os.path.join(directory2,i)
    class_num2=classes2.index(i)
    for img in os.listdir(path):
        img_array2=cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
        img_array2=cv2.imread(os.path.join(path,img))
        #img_array2=cv2.cvtColor(img_array2, cv2.COLOR_BGR2RGB)
        img_array2=cv2.resize(img_array2,(img_size,img_size))
        all_arrays2.append([img_array2,class_num2])

# %%
#Deviding training data into imges and lables to be used in the model
train_images = []
train_labels = []

for features,label in all_arrays:
    train_images.append(features)
    train_labels.append(label)

#converting train_images &train_lables from lists into np arra to fit in the modle
train_images = np.array(train_images)
train_labels = np.array(train_labels)

# %%
#Deviding testing data into imges and lables to be used in the model
test_images = []
test_labels = []

for features,label in all_arrays2:
    test_images.append(features)
    test_labels.append(label)
    
test_images = np.array(test_images)
test_labels = np.array(test_labels)

# %%
#normalization
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
#normalization
train_images = tf.keras.utils.normalize(train_images, axis=1)
test_images = tf.keras.utils.normalize(test_images, axis=1)

# %%
#shuffle the data and print a sample
import random
random.shuffle(all_arrays)
for sample in all_arrays[:15]:
    print(sample[1])
# Out:
# 9
# 11
# 12
# 13
# 7
# 13
# 0
# 11
# 7
# 8
# 10
# 12
# 5
# 2
# 11

# %%
#print the shapes
print(train_images.shape)
print(len(train_labels))
print(train_labels)
print(test_images.shape)
print(len(test_labels))
# Out:
# (6711, 100, 100, 3)
# 6711
# [ 0  0  0 ... 13 13 13]
# (499, 100, 100, 3)
# 499

# %%
#displaying an image
plt.imshow(train_images[4100], cmap=plt.cm.binary)  # graph it
plt.show()  # display!

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(100, 100, 3)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(15, activation=tf.nn.softmax)
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy', # diff between actual and probabilities
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, batch_size = 128, epochs = 10)
# Out:
# Epoch 1/10
# 6711/6711 [==============================] - 32s 5ms/step - loss: 1.1750 - acc: 0.6625
# Epoch 2/10
# 6711/6711 [==============================] - 8s 1ms/step - loss: 0.1784 - acc: 0.9771
# Epoch 3/10
# 6711/6711 [==============================] - 8s 1ms/step - loss: 0.0659 - acc: 0.9945
# Epoch 4/10
# 6711/6711 [==============================] - 8s 1ms/step - loss: 0.0318 - acc: 0.9982
# Epoch 5/10
# 6711/6711 [==============================] - 8s 1ms/step - loss: 0.0163 - acc: 1.0000
# Epoch 6/10
# 6711/6711 [==============================] - 8s 1ms/step - loss: 0.0106 - acc: 1.0000
# Epoch 7/10
# 6711/6711 [==============================] - 8s 1ms/step - loss: 0.0077 - acc: 1.0000
# Epoch 8/10
# 6711/6711 [==============================] - 8s 1ms/step - loss: 0.0058 - acc: 1.0000
# Epoch 9/10
# 6711/6711 [==============================] - 8s 1ms/step - loss: 0.0045 - acc: 1.0000
# Epoch 10/10
# 6711/6711 [==============================] - 8s 1ms/step - loss: 0.0036 - acc: 1.0000

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('Test accuracy:', test_acc)
# Out:
# 499/499 [==============================] - 9s 18ms/step
# Test accuracy: 0.8036072146677541

# %%
predictions = model.predict(test_images)
print(predictions[0])
print(np.argmax(predictions[0]))
print(test_labels[0])
# Out:
# [3.7123942e-01 6.8010114e-02 1.0936946e-03 7.2385133e-06 1.4772193e-04
#  2.0040065e-04 2.6086112e-03 5.4791147e-01 2.0593150e-07 7.8318473e-03
#  2.0025211e-05 7.1925837e-07 6.0212307e-10 9.2860893e-04 1.5519934e-11]
# 7
# 0

# %%
plt.figure()
plt.imshow(train_images[0],cmap='gray')
plt.colorbar()
plt.grid(False)
plt.show()
